# %%
# %run step1.py
# Out:
# [*********************100%***********************]  1 of 1 completed
# Dane dla XGBoost gotowe. X to wszystkie kolumny oprócz Target, Y to Target.

# %%
# %run step2_inspect.py
# Out:
# [*********************100%***********************]  1 of 1 completed
# Saved 6502 rows
#
# Columns: ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume', 'RSI', 'SMA_20', 'ATR', 'Close_Lag_1', 'Volume_Lag_1', 'Close_Lag_2', 'Volume_Lag_2', 'Close_Lag_3', 'Volume_Lag_3', 'Close_Lag_5', 'Volume_Lag_5', 'Close_Lag_10', 'Volume_Lag_10', 'Target']
#
# First 3 rows:
# Price       Adj Close     Close      High       Low      Open     Volume  \
# Date
# 2000-01-31   0.777892  0.926339  0.927455  0.843750  0.901786  701680000
# 2000-02-01   0.751650  0.895089  0.937500  0.892857  0.928571  318035200
# 2000-02-02   0.740872  0.882254  0.911830  0.866071  0.899554  464195200
#
# Price             RSI    SMA_20       ATR  Close_Lag_1  Volume_Lag_1  \
# Date
# 2000-01-31  27.768774  0.922852  0.075128     0.907366   423348800.0
# 2000-02-01  26.499846  0.917634  0.072951     0.926339   701680000.0
# 2000-02-02  25.974842  0.915988  0.071009     0.895089   318035200.0
#
# ...

# %%
# %run step3_train.py
# Out:
# [*********************100%***********************]  1 of 1 completed
# MAE: $64.68
# RMSE: $75.10
#
# Features used: ['RSI', 'SMA_20', 'ATR', 'Close_Lag_1', 'Volume_Lag_1', 'Close_Lag_2', 'Volume_Lag_2', 'Close_Lag_3', 'Volume_Lag_3', 'Close_Lag_5', 'Volume_Lag_5', 'Close_Lag_10', 'Volume_Lag_10']
# Train size: 5201, Test size: 1301

# %%
# %run step4_gen_predictions.py
# Out:
# Pobieranie danych (AAPL + VIX)...
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Pobieranie danych (AAPL + VIX)...
# [*********************100%***********************]  2 of 2 completed
# Trening modelu regresyjnego (XGBoost)...
# Zapisano nowe wyniki. VIX dodany. Zakres danych: 6472 dni.

# %%
# %run step5_meta_model.py
# Out:
# Statystyki modelu kolegów (przed filtrem):
# Skuteczność kierunkowa (Accuracy): 47.18%
#
# Trening Meta-Modelu (Random Forest)...
#
# --- WYNIKI TWOJEGO MODUŁU ---
#               precision    recall  f1-score   support
#
#            0       0.81      0.08      0.15       354
#            1       0.47      0.98      0.63       294
#
#     accuracy                           0.49       648
#    macro avg       0.64      0.53      0.39       648
# weighted avg       0.66      0.49      0.37       648
#
# Precyzja Twojego filtra: 46.97%
# UWAGA: Filtr wymaga dostrojenia (więcej danych/lepsze cechy).
#
# Wykres zapisany jako 'meta_model_comparison.png'
